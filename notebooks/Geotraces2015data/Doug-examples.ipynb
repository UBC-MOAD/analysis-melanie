# %% [markdown]
# ## List examples

# %%
#xxx = []
#for i in range(10):
#    xxx.append(i*2)
xxx = [i*2 for i in range(10) if i < 6] # shorter way to write a simple loop
xxx
# Out:
# [0, 2, 4, 6, 8, 10]

# %% [markdown]
# ## Set examples

# %%
s = {'a', 'b', 'c'}  
s.intersection({'c', 'd', 'e'})
s.add('a') # Contrarily to lists, set creates unique objects, so won't add 'a' as it already exists in the set. 
s
# Out:
# {'a', 'b', 'c'}
